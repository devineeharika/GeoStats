# %%
from numpy import array
import pandas as pd
import numpy
from sklearn.model_selection import KFold


import numpy as np
import matplotlib.pyplot as plt
import time 
import matplotlib.pyplot as plt
df=pd.read_csv('/content/Ocscaled.csv', sep=',',header=None)

# %%
list_data = df.to_numpy().tolist()
print(list_data)
print(type(list_data))
long_data=[]
for i in range(len(list_data)):
  long_data.append([])
  for k in range(2):
    long_data[i].append(list_data[i][k])
print(long_data)
N_data=[]
for i in range(len(list_data)):
  N_data.append(list_data[i][2])
print(N_data)
# Out:
# [[17.895, 73.40100000000001, 0.5404], [17.895, 73.40100000000001, 0.56061], [17.895, 73.402, 0.33838], [17.895, 73.403, 0.88384], [17.895, 73.403, 0.89394], [17.895, 73.404, 0.70202], [17.895, 73.404, 0.75758], [17.895, 73.404, 0.89394], [17.895, 73.405, 0.50505], [17.895, 73.406, 0.75758], [17.895, 73.407, 0.8383799999999999], [17.895, 73.40899999999999, 0.79293], [17.895, 73.434, 0.33838], [17.895, 73.48100000000001, 0.75758], [17.895, 73.482, 0.47475], [17.913, 74.903, 0.31313], [17.913, 74.64, 0.36869], [17.929000000000002, 75.36399999999999, 0.16162], [17.942, 74.883, 0.24747], [17.947, 74.874, 0.19192], [17.947, 74.875, 0.43433999999999995], [17.949, 74.846, 0.23736999999999997], [17.949, 74.847, 0.29798], [17.95, 74.847, 0.43433999999999995], [17.95, 74.846, 0.14645999999999998], [17.95, 74.847, 0.37374], [17.95, 74.852, 0.4798], [17.951, 74.846, 0.11615999999999999], [17.951, 74.848, 0.22221999999999997], [17.951, 74.848, 0.44948999999999995], [17.951, 74.85600000000001, 0.14
# ...

# %%
from scipy.spatial import distance
from collections import OrderedDict 
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import r2_score,mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

def smape(A, F):
    return 100/len(A) * np.sum(2 * np.abs(F - A) / (np.abs(A) + np.abs(F)))
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# import numpy as np
# data = array(list_data)
# kfold = KFold(5, True, 1)


# val_dict = dict()
# val_dict['rmse']=[]
# val_dict['r2']=[]
# val_dict['smape']=[]
# val_dict['mae']=[]

# for train, test in kfold.split(data):
#   rmse_list =[]
#   smape_list=[]
#   mae_list =[]
#   r2_list = []
#   distances =[]
#   train_coordinates =[]
#   for i in range(len(data[train])):
#      train_coordinates.append([])
#      for k in range(2):
#         train_coordinates[i].append(data[train][i][k])
#   # print(data[train][0][0])
#   test_coordinates =[]
#   test_values =[]
#   for i in range(len(data[test])):
#      test_coordinates.append([])
#      for k in range(2):
#        test_coordinates[i].append(data[test][i][k])
#      test_values.append(data[test][i][2])
#   # print(test_coordinates)
  
#   dist_dict=dict()
#   predicted_values =[]
#   for i in range(len(data[test])):
#     distances = (distance.cdist([test_coordinates[i]],train_coordinates , "euclidean" ))
    
#     for j in range(len(distances[0])):
#       dist_dict[j]=distances[0][j]
   
    
#     dist_dict = {k: v for k, v in sorted(dist_dict.items(), key=lambda item: item[1])}
   
#     input_data =[]
#     input_values =[]
#     for k,j in dist_dict.items():
#       if(len(input_data) >900):
#         break
#       if(j > 0.1 ):
#         input_data.append( data[train][k][2]/j)
#         input_values.append(data[test][i][2])  
#     print(np.array(input_data).reshape(-1,1))
#     print("****************************")
#     print(np.array(input_values).reshape(-1,1))
#     print("--------------------------------------")
#     svr_rbf = SVR(kernel='rbf', C=1, gamma=0.1, epsilon=.1)
#     svr_rbf.fit( np.array(input_data).reshape(-1,1),np.array(input_values).reshape(-1,1))

#     predicted_values.append( svr_rbf.predict(np.array(([data[test][i][0] , data[test][i][1]])).reshape(-1,1)))
#     print(predicted_values)
  
#   rmse_list.append( sqrt(mean_squared_error(predicted_values , test_values )))
#   smape_list.append(smape(predicted_values , test_values ))
#   r2_list.append(r2_score(predicted_values , test_values ))
#   mae_list.append(mean_absolute_error(predicted_values , test_values ))

#   val_dict[rmse].append(rmse_list)
#   val_dict[r2].append(r2_list)
#   val_dict[mae].append(mae_list)
#   val_dict[smape].append(smape_list)
# Out:
# [[3.53469863]
#  [0.63256088]
#  [0.29999182]
#  [1.17512447]
#  [0.56054691]
#  [0.91557377]
#  [0.60940689]
#  [1.65570006]
#  [1.13899873]
#  [0.55046117]
#  [0.68211254]
#  [0.81757392]
#  [0.86984752]
#  [1.46654961]
#  [0.89526916]
#  [0.32328989]
#  [0.54944288]
#  [1.64566591]
#  [0.74739889]
#  [1.38599487]
#  [1.66059478]
#  [0.54406832]
#  [1.05435986]
#  [0.57628575]
#  [1.36045914]
#  [0.52063379]
#  [1.75630583]
#  [1.35132465]
#  [1.45375939]
#  [1.5280222 ]
#  [0.9533067 ]
#  [1.53023401]
#  [1.48994708]
#  [1.256194  ]
#  [0.47311893]
#  [0.57381169]
#  [0.87825158]
#  [1.50165242]
#  [1.22948171]
#  [0.33646067]
#  [1.3539128 ]
#  [0.74495931]
#  [0.98654092]
#  [0.33277546]
#  [0.68982722]
#  [0.13525124]
#  [1.48558901]
#  [0.98112767]
#  [0.87039228]
#  [0.50089291]
#  [0.68128077]
#  [1.08172439]
#  [1.44033944]
#  [0.78485367]
#  [1.42039848]
#  [1.38429029]
#  [0.49324056]
#  [0.75756713]
#  [1.17602152]
#  [1.4273799 ]
#  [1.42609347]
#  [0.13178923]
# ...

# %%
import numpy as np
data = array(list_data)
kfold = KFold(5, True, 1)


val_dict = dict()
val_dict['rmse']=[]
val_dict['r2']=[]
val_dict['smape']=[]
val_dict['mae']=[]
dist_dict=dict()
predicted_values =[]

distances = (distance.cdist(data,data, "euclidean" ))
print(distances)
print(len(distances))
svr_dict=dict()
svr_dict['svr_input']=[]
svr_dict['svr_values']=[]

count=0
for i in range(len(distances)):
    for j in range(len(distances[i])):
      dist_dict[j]=distances[i][j]
    dist_dict = {k: v for k, v in sorted(dist_dict.items(), key=lambda item: item[1])}
    input_data =[]
    input_values =[]
    for k,j in dist_dict.items():
      if(len(input_data) >399):
        break
      if(j > 0.1 ):
        input_data.append( data[k][2]/j)
    input_values.append(data[i][2])
    count=count+1
    print(count)
    svr_dict['svr_input'].append(input_data)
    svr_dict['svr_values'].append(input_values)
log_df = pd.DataFrame(svr_dict)
log_df.to_csv('/content/gdrive/My Drive/oc_features_399_Svr.csv')
# Out:
# Streaming output truncated to the last 5000 lines.
# 20943
# 20944
# 20945
# 20946
# 20947
# 20948
# 20949
# 20950
# 20951
# 20952
# 20953
# 20954
# 20955
# 20956
# 20957
# 20958
# 20959
# 20960
# 20961
# 20962
# 20963
# 20964
# 20965
# 20966
# 20967
# 20968
# 20969
# 20970
# 20971
# 20972
# 20973
# 20974
# 20975
# 20976
# 20977
# 20978
# 20979
# 20980
# 20981
# 20982
# 20983
# 20984
# 20985
# 20986
# 20987
# 20988
# 20989
# 20990
# 20991
# 20992
# 20993
# 20994
# 20995
# 20996
# 20997
# 20998
# 20999
# 21000
# 21001
# 21002
# 21003
# 21004
# 21005
# 21006
# 21007
# 21008
# 21009
# 21010
# 21011
# 21012
# 21013
# 21014
# 21015
# 21016
# 21017
# 21018
# 21019
# 21020
# 21021
# 21022
# 21023
# 21024
# 21025
# 21026
# 21027
# 21028
# 21029
# 21030
# 21031
# 21032
# 21033
# 21034
# 21035
# 21036
# 21037
# 21038
# 21039
# 21040
# 21041
# 21042
# 21043
# 21044
# 21045
# 21046
# 21047
# 21048
# 21049
# 21050
# 21051
# 21052
# 21053
# 21054
# 21055
# 21056
# 21057
# 21058
# 21059
# 21060
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
